# %% [markdown]
# # Aplicação do Regex

# %%
import pandas as pd

# %%
data = pd.read_csv('products_hm.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  product_id   product_category   product_name product_price  \
# 0           0  1008549001  men_jeans_regular  Regular Jeans       $ 19.99
# 1           1  1008549001  men_jeans_regular  Regular Jeans       $ 19.99
# 2           2  1008549001  men_jeans_regular  Regular Jeans       $ 19.99
# 3           3  1008549001  men_jeans_regular  Regular Jeans       $ 19.99
# 4           4  1008549001  men_jeans_regular  Regular Jeans       $ 19.99
#
#        scrapy_datetime  style_id  color_id  color_name          Fit  \
# 0  2022-01-29 13:15:13   1008549         1  Denim blue  Regular fit
# 1  2022-01-29 13:15:13   1008549         1  Denim blue  Regular fit
# 2  2022-01-29 13:15:13   1008549         1   Dark blue  Regular fit
# 3  2022-01-29 13:15:13   1008549         1   Dark blue  Regular fit
# 4  2022-01-29 13:15:13   1008549         1       Black  Regular fit
#
#                                 Composition
# 0             Shell: Cotton 98%, Spandex 2%
# 1  Pocket lining: Polyester 65%, Cotton 35%
# 2             Shell: Cotton 98%, Spandex 2%
# 3  Pocket lining: Polyester 65%, Cotton 35%
# 4             Shell: Cotton 98%, Spandex 2%

# %%
data = data.drop(['Unnamed: 0'], axis=1)

# %%
data.head()
# Out:
#    product_id   product_category   product_name product_price  \
# 0  1008549001  men_jeans_regular  regular_jeans         19.99
# 1  1008549001  men_jeans_regular  regular_jeans         19.99
# 2  1008549001  men_jeans_regular  regular_jeans         19.99
# 3  1008549001  men_jeans_regular  regular_jeans         19.99
# 4  1008549001  men_jeans_regular  regular_jeans         19.99
#
#        scrapy_datetime  style_id  color_id  color_name          Fit  \
# 0  2022-01-29 13:15:13   1008549         1  Denim blue  Regular fit
# 1  2022-01-29 13:15:13   1008549         1  Denim blue  Regular fit
# 2  2022-01-29 13:15:13   1008549         1   Dark blue  Regular fit
# 3  2022-01-29 13:15:13   1008549         1   Dark blue  Regular fit
# 4  2022-01-29 13:15:13   1008549         1       Black  Regular fit
#
#                                 Composition
# 0             Shell: Cotton 98%, Spandex 2%
# 1  Pocket lining: Polyester 65%, Cotton 35%
# 2             Shell: Cotton 98%, Spandex 2%
# 3  Pocket lining: Polyester 65%, Cotton 35%
# 4             Shell: Cotton 98%, Spandex 2%

# %%
# Checando NAs
data.isna().sum()
# Out:
# product_id          0
# product_category    0
# product_name        0
# product_price       0
# scrapy_datetime     0
# style_id            0
# color_id            0
# color_name          0
# Fit                 0
# Composition         0
# dtype: int64

# %% [markdown]
# - No caso de existir NA, e não estivermos usando nenhuma técnica de substituição, podemos simplesmente ignorar, usando o comando abaixo.

# %% [markdown]
# `data = data.dropna(subset=['product_id'])`

# %% [markdown]
# - Neste caso, estaríamos removendo todos os NAs da coluna `product_id`.

# %%
# product_name
data['product_name'] = data['product_name'].apply(lambda x: x.replace(' ', '_').lower())

# product_price
data['product_price'] = data['product_price'].apply(lambda x: x.replace('$ ', ''))

# style_id

data.head()
# Out:
#    product_id   product_category   product_name product_price  \
# 0  1008549001  men_jeans_regular  regular_jeans         19.99
# 1  1008549001  men_jeans_regular  regular_jeans         19.99
# 2  1008549001  men_jeans_regular  regular_jeans         19.99
# 3  1008549001  men_jeans_regular  regular_jeans         19.99
# 4  1008549001  men_jeans_regular  regular_jeans         19.99
#
#        scrapy_datetime  style_id  color_id  color_name          Fit  \
# 0  2022-01-29 13:15:13   1008549         1  Denim blue  Regular fit
# 1  2022-01-29 13:15:13   1008549         1  Denim blue  Regular fit
# 2  2022-01-29 13:15:13   1008549         1   Dark blue  Regular fit
# 3  2022-01-29 13:15:13   1008549         1   Dark blue  Regular fit
# 4  2022-01-29 13:15:13   1008549         1       Black  Regular fit
#
#                                 Composition
# 0             Shell: Cotton 98%, Spandex 2%
# 1  Pocket lining: Polyester 65%, Cotton 35%
# 2             Shell: Cotton 98%, Spandex 2%
# 3  Pocket lining: Polyester 65%, Cotton 35%
# 4             Shell: Cotton 98%, Spandex 2%

# %%
data.dtypes
# Out:
# Unnamed: 0           int64
# product_id           int64
# product_category    object
# product_name        object
# product_price       object
# scrapy_datetime     object
# style_id             int64
# color_id             int64
# color_name          object
# Fit                 object
# Composition         object
# dtype: object

# %%
# Out:
#       product_id   product_category   product_name product_price  \
# 0     1008549001  men_jeans_regular  regular_jeans         19.99
# 1     1008549001  men_jeans_regular  regular_jeans         19.99
# 2     1008549001  men_jeans_regular  regular_jeans         19.99
# 3     1008549001  men_jeans_regular  regular_jeans         19.99
# 4     1008549001  men_jeans_regular  regular_jeans         19.99
# ...          ...                ...            ...           ...
# 1960   875105024  men_jeans_relaxed  relaxed_jeans         29.99
# 1961   875105024  men_jeans_relaxed  relaxed_jeans         29.99
# 1962   875105024  men_jeans_relaxed  relaxed_jeans         29.99
# 1963   875105024  men_jeans_relaxed  relaxed_jeans         29.99
# 1964   875105024  men_jeans_relaxed  relaxed_jeans         29.99
#
#           scrapy_datetime  style_id  color_id       color_name          Fit  \
# 0     2022-01-29 13:15:13   1008549         1       Denim blue  Regular fit
# 1     2022-01-29 13:15:13   1008549         1       Denim blue  Regular fit
# 2     2022-01-29 13:15:13   1008549         1        Dark blue  Regular fit
# 3     2022-01-29 13:15:13   1008549         1        Dark blue  Regular fit
# 4     2022-01-29 13:15:13   1008549         1            Black  Regular fit
# ...                   ...       ...       ...              ...          ...
# 1960  2022-01-29 13:15:13    875105        24  Dark denim blue  Relaxed fit
# 1961  2022-01-29 13:15:13    875105        24  Pale denim blue  Relaxed fit
# 1962  2022-01-29 13:15:13    875105        24  Pale denim blue  Relaxed fit
# 1963  2022-01-29 13:15:13    875105        24            Black  Relaxed fit
# 1964  2022-01-29 13:15:13    875105        24            Black  Relaxed fit
#
#                                    Composition
# 0                Shell: Cotton 98%, Spandex 2%
# 1     Pocket lining: Polyester 65%, Cotton 35%
# 2                Shell: Cotton 98%, Spandex 2%
# 3     Pocket lining: Polyester 65%, Cotton 35%
# 4                Shell: Cotton 98%, Spandex 2%
# ...                                        ...
# 1960  Pocket lining: Polyester 65%, Cotton 35%
# 1961                        Shell: Cotton 100%
# 1962  Pocket lining: Polyester 65%, Cotton 35%
# 1963                        Shell: Cotton 100%
# 1964  Pocket lining: Polyester 65%, Cotton 35%
#
# [1965 rows x 10 columns]
